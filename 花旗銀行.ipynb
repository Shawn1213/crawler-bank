# %%
import requests
from bs4 import BeautifulSoup
import re
import json
import codecs

url = 'http://www.citibank.com.tw/global_docs/chi/cb/jfp_qa/index.htm'   #花旗銀行----網路銀行服務介紹(Q&A)
res = requests.get(url)
res.encoding = 'utf8'
soup = BeautifulSoup(res.text)
#print soup

# %%
texts=[]
content = soup.select('table')[6:13:3]   #把table15拿掉(第4題)
for Content in content:
    texts.append(Content)
content2 = soup.select('table')[19:-1:3]
for Content2 in content2:
    texts.append(Content2)

Q=[]
A=[]
for all_texts in texts:
    all_Texts = ''.join((all_texts.text).split()).replace('&nbsp','').replace('goto:立即註冊'.decode('utf8'),'')\
    .replace('goto:忘記網路使用者代號'.decode('utf8'),'').replace('goto:忘記網路登入密碼'.decode('utf8'),'')\
    .replace('goto:重設網路登入密碼'.decode('utf8'),'').replace('SMSOTP','SMS OTP').replace('iPadorAndroidPad','iPad or Android Pad')
    question = re.findall('Q:(.*)A:',all_Texts)
    for Question in question:
        #print Question
        Q.append(Question)
    answer = re.findall('A:(.*)',all_Texts)
    for Answer in answer:
        #print Answer
        A.append(Answer)

j=1
for all_q,all_a in zip(Q,A):
    
    y = {'bank':'citibank','class':'netbank','Q':all_q,'A':all_a} #json格式
        #key統一為bank:value自取  key統一為class:value統一請參考EXCEL  
        #銀行名稱統一小寫英文，取完之後打在EXCEL上
    
    json_qa = json.dumps(y,ensure_ascii=False,indent=2) #轉檔轉碼  
    print json_qa   #print檢查一下
                                                         
#    with codecs.open('C:/Users/vitacake/Desktop/citibank/netbank/citibank_netbank_{}.json'.format(j),'wb') as fout: 
#        json.dump(y , fout)  #寫入檔案，並關檔
#    j += 1
# Out:
# {
#   "Q": "銀行客戶如何註冊？",
#   "A": "步驟1:點選「花旗網路銀行/註冊」。步驟2:點選「金融卡」註冊網路使用者代號。步驟3:輸入您的金融卡/晶片卡/網銀辨識卡卡號。步驟4:利用電腦螢幕上的動態鍵盤點選晶片卡/金融卡磁條密碼。步驟5:輸入您名下的任一帳戶號碼(如：一般活存、支票存款或綜合外幣存款等)。步驟6:輸入您手機收到的「簡訊動態密碼SMS OTP」步驟7:設定您的網路使用者代號。步驟8:利用電腦螢幕上的動態鍵盤點選網路登入密碼。步驟9:再次點選確認網路登入密碼。步驟10:仔細閱讀網路銀行服務同意書後按「同意」。步驟11:按「回到我的首頁」，開始使用花旗網路銀行。",
#   "class": "netbank",
#   "bank": "citibank"
# }
# {
#   "Q": "信用卡/ReadyCash卡客戶如何註冊﹝已有預借現金密碼﹞？",
#   "A": "步驟1:點選「花旗網路銀行/註冊」。步驟2:點選「信用卡與預借現金密碼」註冊網路使用者代號。步驟3:輸入您的信用卡/ReadyCash卡卡號。步驟4:利用電腦螢幕上的動態鍵盤點選信用卡/ReadyCash卡預借現金密碼。步驟5:再次輸入您的信用卡/ReadyCash卡號。步驟6:輸入您手機收到的「簡訊動態密碼SMS OTP」步驟7:設定您的網路使用者代號。步驟8:利用電腦螢幕上的動態鍵盤點選網路登入密碼。步驟9:再次點選確認網路登入密碼。步驟10:仔細閱讀網路銀行服務同意書後按「同意」。步驟11:按「回到我的首頁」，開始使用花旗網路銀行。",
#   "class": "netbank",
#   "bank": "citibank"
# }
# {
#   "Q": "信用卡客戶沒有預借現金密碼，該如何註冊？",
# ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import json
import codecs

url = 'https://webatm.citibank.com.tw/faq.jsp'     #花旗銀行---網路ATM(共16題刪第6題)剩15題(json檔
res = requests.get(url)
soup = BeautifulSoup(res.text)
content = soup.select('table .q')
content2 = soup.select('table .a')
Q = []
A = []
for question in content:
    Ques = ''.join((question.text).split())
    Question = re.sub('\d+\.','',Ques)
    Q.append(Question)
for answer in content2:
    Answer = ''.join((answer.text).split())
    A.append(Answer)

j=1
del Q[5]
del A[5]
for all_q, all_a in zip(Q, A):
#    print all_q,all_a
    y = {'bank':'citibank','class':'atm','Q':all_q,'A':all_a} #json格式
        #key統一為bank:value自取  key統一為class:value統一請參考EXCEL  
        #銀行名稱統一小寫英文，取完之後打在EXCEL上
    
    json_qa = json.dumps(y,ensure_ascii=False,indent=2) #轉檔轉碼  
    print json_qa   #print檢查一下
                                                        
#    with codecs.open('C:/Users/vitacake/Desktop/citibank/atm/citibank_atm_{}.json'.format(j),'wb') as fout: 
#        json.dump(y , fout)  #寫入檔案，並關檔
#    j += 1
# Out:
# {
#   "Q": "什麼是花旗(台灣)銀行網路ATM?",
#   "A": "透過花旗(台灣)銀行網路ATM,結合您的晶片卡及讀卡機,提供您除了提款功能外之其他的ATM服務,如餘額查詢,轉帳,繳費及變更晶片卡密碼。",
#   "class": "atm",
#   "bank": "citibank"
# }
# {
#   "Q": "使用花旗(台灣)銀行網路ATM需要事先申請嗎?",
#   "A": "您無需特別申請,只要您持有晶片卡及讀卡機且您的電腦具備上網功能,透過IE6.0以上的瀏覽器,即享受花旗(台灣)銀行網路ATM的便利。",
#   "class": "atm",
#   "bank": "citibank"
# }
# {
#   "Q": "花旗(台灣)銀行網路ATM支援瀏覽器版本?",
#   "A": "支援MicrosoftIE6.0以上版本,目前暫不支援其他的瀏覽器,如：FireFox,GoogleChrome",
#   "class": "atm",
#   "bank": "citibank"
# }
# {
#   "Q": "花旗(台灣)銀行網路ATM可以查詢我的所有交易明細嗎?",
#   "A": "目前只提供該張晶片卡在本行網路ATM的交易明細,若您需要更完整詳細的資訊,請洽您的發卡行。",
#   "class": "atm",
#   "bank": "citibank"
# }
# {
#   "Q": "什麼是晶片卡約定轉入帳號、常用帳號？和預設帳號有什麼不同?",
#   "A": "晶片卡約定轉入帳號(Pre-setaccount)–即您在發卡行設定寫入晶片卡中的帳號，轉帳限額則取決於是否與發卡行簽有書面約定轉帳金額不受三萬元限制。常用帳號-當您在花旗(台灣)銀行網路ATM設定了常用帳號,未來您在花旗(台灣)銀行網路ATM轉帳交易時，就無需重覆輸入該帳戶資料。預設帳號(Pre-destinatedaccount)–客戶以書面和發卡行約定,指定為特定轉入帳號,轉帳時金額不受三萬元的限制。",
#   "class": "atm",
#   "bank": "citibank"
# }
# {
#   "Q": "花旗(台灣)銀行網路ATM收費標準。",
# ...
